# %% [markdown]
# # Effect of front pyramid texture and/or rear grating on absorption in Si
#
# This example is based on Figures 6, 7 and 8 from [this paper](https://doi.org/10.1364/OE.23.0A1720).
# This compares three different structures, all based on a 200 micron thick slab of silicon
# with different surface textures:
#
# 1. Planar front surface (TMM), crossed grating at rear (RCWA)
# 2. Inverted pyramids on the front surface (RT_Fresnel), planar rear surface (TMM)
# 3. Inverted pyramids on the front surface (RT_Fresnel), crossed grating at rear (RCWA)
#
# The methods which will be used to calculate the redistribution matrices in each case are given in
# brackets. If case 1 and 2 are calculated first, then case 3 does not require the calculations of
# any additional matrices, since it will use the rear matrix from (1) and the front matrix from (2).
#
# First, importing relevant packages:

# %%
import numpy as np
import os
# solcore imports
from solcore.structure import Layer
from solcore import material
from solcore import si
from rayflare.structure import Interface, BulkLayer, Structure
from rayflare.matrix_formalism import process_structure, calculate_RAT
from rayflare.transfer_matrix_method import tmm_structure
from rayflare.angles import theta_summary
from rayflare.textures import regular_pyramids
from rayflare.options import default_options
from solcore.material_system import create_new_material
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# To make sure we are using the same optical constants for Si, load the same Si n/k data used in the paper
# linked above:

# %%
create_new_material('Si_OPTOS', 'data/Si_OPTOS_n.txt', 'data/Si_OPTOS_k.txt')

# %% [markdown]
# You only need to do this one time, then the material will be stored in Solcore's material database.
#
# Setting options (taking the default options for everything not specified explicitly):

# %%
angle_degrees_in = 8

wavelengths = np.linspace(900, 1200, 30)*1e-9

Si = material('Si_OPTOS')()
Air = material('Air')()

options = default_options()
options.wavelengths = wavelengths
options.theta_in = angle_degrees_in*np.pi/180
options.n_theta_bins = 50
options.n_rays = 67600
options.project_name = 'OPTOS_comparison'
options.orders = 60

# %% [markdown]
# Now, set up the grating basis vectors for the RCWA calculations and define the grating structure.
# These are squares, rotated by 45 degrees. The halfwidth is calculated based on the area fill factor
# of the etched pillars given in the paper.

# %%
x = 1000

d_vectors = ((x, 0),(0,x))
area_fill_factor = 0.36
hw = np.sqrt(area_fill_factor)*500

back_materials = [Layer(si('120nm'), Si, geometry=[{'type': 'rectangle', 'mat': Air, 'center': (x/2, x/2),
                                                     'halfwidths': (hw, hw), 'angle': 45}])]

# %% [markdown]
# Now we define the pyramid texture for the front surface in case (2) and (3) and make the four
# possible different surfaces: planar front and rear, front with pyramids, rear with grating.
# We specify the method to use to calculate the redistribution matrices in each case and create
# the bulk layer.

# %%
surf = regular_pyramids(elevation_angle=55, upright=False)

front_surf_pyramids = Interface('RT_Fresnel', texture = surf, layers=[],
                                name = 'inv_pyramids_front_' + str(options['n_rays']))

front_surf_planar = Interface('TMM', layers=[], name='planar_front')

back_surf_grating = Interface('RCWA', layers=back_materials, name='crossed_grating_back',
                              d_vectors=d_vectors, rcwa_orders=60)

back_surf_planar = Interface('TMM', layers=[], name = 'planar_back')

bulk_Si = BulkLayer(201.8e-6, Si, name = 'Si_bulk')

# %% [markdown]
# Now we create the different structures and 'process' them (this will calculate the relevant
# matrices if necessary, or do nothing if it finds the matrices have previously been calculated and
# the files already exist). We don't need to process the final structure because it will use matrices
# calculated for SC_fig6 and SC_fig7.

# %%
SC_fig6 = Structure([front_surf_planar, bulk_Si, back_surf_grating], incidence=Air, transmission=Air)
SC_fig7 = Structure([front_surf_pyramids, bulk_Si, back_surf_planar], incidence=Air, transmission=Air)
SC_fig8 = Structure([front_surf_pyramids, bulk_Si, back_surf_grating], incidence=Air, transmission=Air)

process_structure(SC_fig6, options)
process_structure(SC_fig7, options)
# Out:
# Making matrix for planar surface using TMM for element 0 in structure
# Existing angular redistribution matrices found
# Existing angular redistribution matrices found
# RCWA calculation for element 2 in structure
# Existing angular redistribution matrices found
# Ray tracing with Fresnel equations for element 0 in structure
# Existing angular redistribution matrices found
# Existing angular redistribution matrices found
# Making matrix for planar surface using TMM for element 2 in structure
# Existing angular redistribution matrices found

# %% [markdown]
# Then we ask RayFlare to calculate the reflection, transmission and absorption through matrix
# multiplication, and get the required result out (absorption in the bulk) for each cell. We
# also load the results from the reference paper to compare them to the ones calculated with RayFlare.

# %%
results_fig6= calculate_RAT(SC_fig6, options)
results_fig7 = calculate_RAT(SC_fig7, options)
results_fig8 = calculate_RAT(SC_fig8, options)

RAT_fig6 = results_fig6[0]
RAT_fig7 = results_fig7[0]
RAT_fig8 = results_fig8[0]

sim_fig6 = np.loadtxt('data/optos_fig6_sim.csv', delimiter=',')
sim_fig7 = np.loadtxt('data/optos_fig7_sim.csv', delimiter=',')
sim_fig8 = np.loadtxt('data/optos_fig8_sim.csv', delimiter=',')
# Out:
# After iteration 1 : maximum power fraction remaining = 0.2901109088010337
# After iteration 2 : maximum power fraction remaining = 0.23676206622967993
# After iteration 3 : maximum power fraction remaining = 0.20881150397680093
# After iteration 4 : maximum power fraction remaining = 0.18689523853768775
# After iteration 5 : maximum power fraction remaining = 0.16835188697174874
# After iteration 6 : maximum power fraction remaining = 0.1523735597868818
# After iteration 7 : maximum power fraction remaining = 0.13846383057059936
# After iteration 8 : maximum power fraction remaining = 0.12625851822762163
# After iteration 9 : maximum power fraction remaining = 0.11547678577867589
# After iteration 10 : maximum power fraction remaining = 0.10598668374288603
# After iteration 11 : maximum power fraction remaining = 0.09757793099474953
# After iteration 12 : maximum power fraction remaining = 0.0900406925588349
# After iteration 13 : maximum power fraction remaining = 0.08325466454331752
# After iteration 14 : maximum power fraction remaining = 0.07712175449731373
# After iteration 15 : maximum power fraction remaining = 0.07156111367698934
# After iteration 16 : maximum power fraction remaining = 0.06650534619572074
# After iteration 17 : maximum power fraction remaining = 0.06189763179350805
# After iteration 18 : maximum power fraction remaining = 0.057689547359947885
# After iteration 19 : maximum power fraction remaining = 0.053839415670865684
# After iteration 20 : maximum power fraction remaining = 0.050311047945932774
# After iteration 21 : maximum power fraction remaining = 0.04707277887662345
# After iteration 22 : maximum power fraction remaining = 0.04409671848478089
# After iteration 23 : maximum power fraction remaining = 0.041358165058624566
# After iteration 24 : maximum power fraction remaining = 0.03883513837807205
# After iteration 25 : maximum power fraction remaining = 0.036508003484897925
# After iteration 26 : maximum power fraction remaining = 0.03435916329723418
# After iteration 27 : maximum power fraction remaining = 0.03237280418132381
# After iteration 28 : maximum power fraction remaining = 0.03053468277989882
# After iteration 29 : maximum power fraction remaining = 0.028831945411150132
# After iteration 30 : maximum power fraction remaining = 0.02725297352892176
# After iteration 31 : maximum power fraction remaining = 0.025787250314132152
# After iteration 32 : maximum power fraction remaining = 0.02442524462093265
# After iteration 33 : maximum power fraction remaining = 0.023158309350117603
# After iteration 34 : maximum power fraction remaining = 0.021978591952530224
# After iteration 35 : maximum power fraction remaining = 0.020878955237288693
# After iteration 36 : maximum power fraction remaining = 0.01985290701661995
# After iteration 37 : maximum power fraction remaining = 0.0188945373916472
# After iteration 38 : maximum power fraction remaining = 0.01799846269369524
# After iteration 39 : maximum power fraction remaining = 0.017159775259520182
# After iteration 40 : maximum power fraction remaining = 0.016373998347966167
# After iteration 41 : maximum power fraction remaining = 0.01563704560843085
# After iteration 42 : maximum power fraction remaining = 0.01494518459447253
# After iteration 43 : maximum power fraction remaining = 0.014295003883578862
# After iteration 44 : maximum power fraction remaining = 0.013683383420012147
# After iteration 45 : maximum power fraction remaining = 0.01310746774434711
# After iteration 46 : maximum power fraction remaining = 0.012564641812774006
# After iteration 47 : maximum power fraction remaining = 0.01205250914292574
# After iteration 48 : maximum power fraction remaining = 0.01156887205201838
# After iteration 49 : maximum power fraction remaining = 0.011111713778323496
# After iteration 50 : maximum power fraction remaining = 0.010679182299074219
# After iteration 51 : maximum power fraction remaining = 0.01026957567735474
# After iteration 52 : maximum power fraction remaining = 0.00988132878773608
# After iteration 1 : maximum power fraction remaining = 0.8057075329542558
# After iteration 2 : maximum power fraction remaining = 0.7039373857822788
# After iteration 3 : maximum power fraction remaining = 0.6128293150406569
# After iteration 4 : maximum power fraction remaining = 0.5325987365588081
# After iteration 5 : maximum power fraction remaining = 0.4651128753467279
# After iteration 6 : maximum power fraction remaining = 0.40538797045457586
# After iteration 7 : maximum power fraction remaining = 0.3540285875683059
# After iteration 8 : maximum power fraction remaining = 0.3089530574598735
# After iteration 9 : maximum power fraction remaining = 0.26985054501627337
# After iteration 10 : maximum power fraction remaining = 0.23565672747923266
# After iteration 11 : maximum power fraction remaining = 0.20587915975713156
# After iteration 12 : maximum power fraction remaining = 0.1798642627401867
# After iteration 13 : maximum power fraction remaining = 0.15715658173724723
# After iteration 14 : maximum power fraction remaining = 0.13731717380726724
# After iteration 15 : maximum power fraction remaining = 0.1199869409246012
# After iteration 16 : maximum power fraction remaining = 0.10484424688953878
# After iteration 17 : maximum power fraction remaining = 0.091613625763899
# After iteration 18 : maximum power fraction remaining = 0.08005266187257518
# After iteration 19 : maximum power fraction remaining = 0.06995081990399185
# After iteration 20 : maximum power fraction remaining = 0.061123727003437274
# After iteration 21 : maximum power fraction remaining = 0.053410571881353015
# After iteration 22 : maximum power fraction remaining = 0.04667073144814873
# After iteration 23 : maximum power fraction remaining = 0.04078139818056902
# After iteration 24 : maximum power fraction remaining = 0.03563523345767522
# After iteration 25 : maximum power fraction remaining = 0.031138461514366746
# After iteration 26 : maximum power fraction remaining = 0.027209132420780116
# After iteration 27 : maximum power fraction remaining = 0.023775642154916725
# After iteration 28 : maximum power fraction remaining = 0.020775420316627224
# After iteration 29 : maximum power fraction remaining = 0.018153793448670477
# After iteration 30 : maximum power fraction remaining = 0.01586298678492043
# After iteration 31 : maximum power fraction remaining = 0.013861254523107335
# After iteration 32 : maximum power fraction remaining = 0.012112118611795727
# After iteration 33 : maximum power fraction remaining = 0.010583704199995037
# After iteration 34 : maximum power fraction remaining = 0.009248158671336635
# After iteration 1 : maximum power fraction remaining = 0.8263758625095932
# After iteration 2 : maximum power fraction remaining = 0.6958441417273615
# After iteration 3 : maximum power fraction remaining = 0.5917877988222274
# After iteration 4 : maximum power fraction remaining = 0.5036718680623182
# After iteration 5 : maximum power fraction remaining = 0.42876750709069145
# After iteration 6 : maximum power fraction remaining = 0.3649789685218802
# After iteration 7 : maximum power fraction remaining = 0.31068173547415956
# After iteration 8 : maximum power fraction remaining = 0.26446372452028294
# After iteration 9 : maximum power fraction remaining = 0.22512254121512038
# After iteration 10 : maximum power fraction remaining = 0.19163384430022637
# After iteration 11 : maximum power fraction remaining = 0.16312697393873832
# After iteration 12 : maximum power fraction remaining = 0.13886071591202553
# After iteration 13 : maximum power fraction remaining = 0.11820423956562906
# After iteration 14 : maximum power fraction remaining = 0.100620556361015
# After iteration 15 : maximum power fraction remaining = 0.08565256613396015
# After iteration 16 : maximum power fraction remaining = 0.07291116616589095
# After iteration 17 : maximum power fraction remaining = 0.062065135897905736
# After iteration 18 : maximum power fraction remaining = 0.052832526181903934
# After iteration 19 : maximum power fraction remaining = 0.044973329756468436
# After iteration 20 : maximum power fraction remaining = 0.03828324207917165
# After iteration 21 : maximum power fraction remaining = 0.03258835029675962
# After iteration 22 : maximum power fraction remaining = 0.027740612272963778
# After iteration 23 : maximum power fraction remaining = 0.02363476220703562
# After iteration 24 : maximum power fraction remaining = 0.02015002436182855
# After iteration 25 : maximum power fraction remaining = 0.01717908046739023
# After iteration 26 : maximum power fraction remaining = 0.014646176123942414
# After iteration 27 : maximum power fraction remaining = 0.01248672625177646
# After iteration 28 : maximum power fraction remaining = 0.010645668273230761
# After iteration 29 : maximum power fraction remaining = 0.009076058103504016

# %% [markdown]
# Finally, we use TMM to calculate the absorption in a structure with a planar front and planar rear,
# as a reference.

# %%
struc = tmm_structure([Layer(si('200um'), Si)], incidence=Air, transmission=Air)
options.coherent = False
options.coherency_list = ['i']
RAT = tmm_structure.calculate(struc, options)

# %% [markdown]
# Plot everything together:

# %%
palhf = sns.color_palette("hls", 4)

fig = plt.figure()
plt.plot(sim_fig6[:,0], sim_fig6[:,1], '--', color=palhf[0], label= 'OPTOS - rear grating (1)')
plt.plot(wavelengths*1e9, RAT_fig6['A_bulk'][0], '-o', color=palhf[0], label='RayFlare - rear grating (1)', fillstyle='none')
plt.plot(sim_fig7[:,0], sim_fig7[:,1], '--', color=palhf[1],  label= 'OPTOS - front pyramids (2)')
plt.plot(wavelengths*1e9, RAT_fig7['A_bulk'][0], '-o', color=palhf[1],  label= 'RayFlare - front pyramids (2)', fillstyle='none')
plt.plot(sim_fig8[:,0], sim_fig8[:,1], '--', color=palhf[2],  label= 'OPTOS - grating + pyramids (3)')
plt.plot(wavelengths*1e9, RAT_fig8['A_bulk'][0], '-o', color=palhf[2],  label= 'RayFlare - grating + pyramids (3)', fillstyle='none')
plt.plot(wavelengths*1e9, RAT['A_per_layer'][:,0], '-k', label='Planar')
plt.legend(loc='lower left')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Absorption in Si')
plt.xlim([900, 1200])
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# We can see good agreement between the reference values and our calculated values. The structure
# with rear grating also behaves identically to the planar TMM reference case at the short wavelengths
# where front surface reflection dominates the result, as expected. Clearly, the pyramids perform
# much better overall, giving a large boost in the absorption at long wavelengths and also reducing the reflection
# significantly at shorter wavelengths. Plotting reflection and transmission emphasises this:

# %%
fig = plt.figure()
plt.plot(wavelengths*1e9, RAT_fig6['R'][0], '-o', color=palhf[0], label='RayFlare - rear grating (1)', fillstyle='none')
plt.plot(wavelengths*1e9, RAT_fig7['R'][0], '-o', color=palhf[1],  label= 'RayFlare - front pyramids (2)', fillstyle='none')
plt.plot(wavelengths*1e9, RAT_fig8['R'][0], '-o', color=palhf[2],  label= 'RayFlare - grating + pyramids (3)', fillstyle='none')

plt.plot(wavelengths*1e9, RAT_fig6['T'][0], '--o', color=palhf[0])
plt.plot(wavelengths*1e9, RAT_fig7['T'][0], '--o', color=palhf[1])
plt.plot(wavelengths*1e9, RAT_fig8['T'][0], '--o', color=palhf[2])

# these are just to create the legend:
plt.plot(-1, 0, 'k-o', label='R', fillstyle='none')
plt.plot(-1, 0, 'k--o', label='T')

plt.legend()
plt.xlabel('Wavelength (nm)')
plt.ylabel('Reflected/transmitted fraction')
plt.xlim([900, 1200])
plt.ylim([0, 0.6])
plt.show()
